# %%
import pandas as pd

# %%
df = pd.read_csv('can_lab_data.csv')

# %%
df.shape
# Out:
# (1928, 56)

# %%
df.describe()
# Out:
#         Unnamed: 0  Percent Indica  Percent Sativa  THC Percent  \
# count  1928.000000     1751.000000     1751.000000  1748.000000
# mean    963.500000        0.530560        0.469189     0.198564
# std     556.709978        0.197287        0.197694     0.048413
# min       0.000000        0.050000        0.050000     0.010000
# 25%     481.750000        0.400000        0.300000     0.175000
# 50%     963.500000        0.500000        0.500000     0.200000
# 75%    1445.250000        0.700000        0.600000     0.230000
# max    1927.000000        0.950000        0.950000     0.340000
#
#        Generated Description       Rating  cis-Nerolidol  trans-Nerolidol  \
# count                    0.0  1093.000000          120.0       120.000000
# mean                     NaN     4.358097            0.0         0.002826
# std                      NaN     0.526862            0.0         0.013342
# min                      NaN     0.000000            0.0         0.000000
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0      Strain    Type  Percent Indica  Percent Sativa  \
# 0           0  sugar-cane  hybrid            0.40            0.60
# 1           1    chemdawg  hybrid            0.55            0.45
# 2           2  jack-herer  sativa             NaN             NaN
#
#    THC Percent                                      Description 1  \
# 0         0.20  Sugar Cane is a rare slightly sativa dominant ...
# 1         0.19  With a near-even balance between sativa and in...
# 2         0.23  Jack Herer is easily one of the best-known str...
#
#                                        Description 2  Generated Description  \
# 0                                                NaN                    NaN
# 1  Chemdawg has developed quite the name for itse...                    NaN
# 2  Jack Herer is a sativa-dominant cannabis strai...                    NaN
#
#                                               Flavor  ...       CBD  CBDV  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Strain', 'Type', 'Percent Indica', 'Percent Sativa',
#        'THC Percent', 'Description 1', 'Description 2',
#        'Generated Description', 'Flavor', 'Effects', 'Rating', 'labs',
#        'cis-Nerolidol', 'trans-Nerolidol', 'trans-Nerolidol 1',
#        'trans-Nerolidol 2', 'trans-Ocimene', '3-Carene', 'Camphene',
#        'Caryophyllene Oxide', 'Eucalyptol', 'Geraniol', 'Guaiol', 'Isopulegol',
#        'Linalool', 'Ocimene', 'Terpinolene', 'alpha-Bisabolol',
#        'alpha-Humulene', 'alpha-Pinene', 'alpha-Terpinene',
#        'beta-Caryophyllene', 'beta-Myrcene', 'beta-Ocimene', 'beta-Pinene',
#        'delta-Limonene', 'gamma-Terpinene', 'p-Cymene', 'delta-9 THC-A',
#        'delta-9 THC', 'delta-8 THC', 'THC-A', 'THCV', 'CBN', 'CBD-A', 'CBD',
#        'CBDV', 'CBDV-A', 'delta-9 CBG-A', 'delta-9 CBG', 'CBC',
#        'Moisture Content', 'ana360', 'psilabs', 'sclabs'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# Strain                      0
# Type                        0
# Percent Indica            177
# Percent Sativa            177
# THC Percent               180
# Description 1               0
# Description 2             903
# Generated Description    1928
# Flavor                      1
# Effects                     8
# Rating                    835
# labs                        0
# cis-Nerolidol            1808
# trans-Nerolidol          1808
# trans-Nerolidol 1        1703
# trans-Nerolidol 2        1703
# trans-Ocimene            1927
# 3-Carene                 1250
# Camphene                 1250
# Caryophyllene Oxide       237
# Eucalyptol               1250
# Geraniol                 1250
# Guaiol                   1250
# Isopulegol               1250
# Linalool                  201
# Ocimene                  1163
# Terpinolene               201
# alpha-Bisabolol          1250
# alpha-Humulene            201
# alpha-Pinene              201
# ...

# %%
analgesic = ['delta-9 THC', 'CBD', 'CBG-A', 'delta-8 THC', 'CBN', 'Linalool',
             'beta-Myrcene', 'alpha-Myrcene']
anoretic = ['THCV']
antibacterial = ['CBD', 'delta-9 CBG-A', 'delta-9 CBG']
anti_diabetic = ['CBD']
antidepressant = ['delta-Limonene']
anti_emetic = ['delta-9 THC', 'CBD']
anti_epileptic = ['CBD', 'Linalool', 'THCV']
antifuntal = ['delta-Limonene', 'Caryophyllene Oxide']
anti_inflammatory = ['CBD', 'CBC', 'delta-9 CBG-A', 'CBD-A', 'beta-Myrcene',
                     'alpha-Myrcene', 'alpha-Pinene', 'beta-Caryophyllene']
anti_insomnia = ['delta-9 CBG', 'THC-A']
anti_ischemic = ['CBD']
antiproliferative = ['CBD', 'CBC', 'delta-Limonene', 'delta-9 CBG', 'CBD-A', 
                     'THC-A']
antipsioratic = ['CBD']
antipsychotic = ['CBD', 'Linalool', 'beta-Myrcene', 'alpha-Myrcene']
antispacmodic = ['delta-9 THC', 'CBD', 'beta-Myrcene', 'alpha-Myrcene', 'THC-A']
anxiolitic = ['CBD']
appetite_stimulant = ['delta-9 THC']
bone_stimulant = ['CBC', 'THCV', 'delta-9 CBG', 'CBD']
gastro_oesophageal_reflux = ['CBC', 'THCV', 'delta-9 CBG', 'CBD']
immunostimulant = ['delta-Limonene']
immunosuppressive = ['CBD']
intestinal_anti_prokinetic = ['CBD']
neuroprotectant = ['CBD']
vasorelaxant = ['CBD']
